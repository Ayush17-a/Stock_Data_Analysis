# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from copy import copy
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go

# %%
stock_df = pd.read_csv('/content/sample_data/stock.csv')
stock_df
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     12-01-2012   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     13-01-2012   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     17-01-2012   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     18-01-2012   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     19-01-2012   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  05-08-2020  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  06-08-2020  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  07-08-2020  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  10-08-2020  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# ...

# %%
# stocks_df = stock_df.sort_values(['Date'])
# stocks_df

# %%
'Total No. of Companies Stocks: {}'.format(len(stock_df.columns[1:]))
# Out:
# 'Total No. of Companies Stocks: 9'

# %%
stock_df.columns
# Out:
# Index(['Date', 'AAPL', 'BA', 'T', 'MGM', 'AMZN', 'IBM', 'TSLA', 'GOOG',
#        'sp500'],
#       dtype='object')

# %%
"Name of Stocks:".format(print(stock_df.columns[1:]))
# Out:
# Index(['AAPL', 'BA', 'T', 'MGM', 'AMZN', 'IBM', 'TSLA', 'GOOG', 'sp500'], dtype='object')
# 'Name of Stocks:'

# %%
print("Name of stocks:")
for i in stock_df.columns[1:]:
  print(i)
  # print("Name of stocks: {}".format(i))
# Out:
# Name of stocks:
# AAPL
# BA
# T
# MGM
# AMZN
# IBM
# TSLA
# GOOG
# sp500

# %%
stock_df.mean()
# Out:
# AAPL      140.819823
# BA        189.942700
# T          35.162899
# MGM        23.105743
# AMZN      915.665665
# IBM       161.853001
# TSLA      259.600815
# GOOG      783.712512
# sp500    2218.749554
# dtype: float64

# %%
stock_df.std()
# Out:
# AAPL      70.827601
# BA       103.678586
# T          3.207490
# MGM        6.963847
# AMZN     697.838905
# IBM       25.561938
# TSLA     210.988003
# GOOG     334.448057
# sp500    537.321727
# dtype: float64

# %%
stock_df.describe()
# Out:
#               AAPL           BA  ...         GOOG        sp500
# count  2159.000000  2159.000000  ...  2159.000000  2159.000000
# mean    140.819823   189.942700  ...   783.712512  2218.749554
# std      70.827601   103.678586  ...   334.448057   537.321727
# min      55.790001    67.239998  ...   278.481171  1278.040039
# 25%      89.165714   124.015000  ...   527.214416  1847.984985
# 50%     116.599998   142.419998  ...   737.599976  2106.629883
# 75%     175.019997   297.044998  ...  1079.744995  2705.810059
# max     455.609985   440.619995  ...  1568.489990  3386.149902
#
# [8 rows x 9 columns]

# %%
stock_df.isnull().sum()
# Out:
# Date     0
# AAPL     0
# BA       0
# T        0
# MGM      0
# AMZN     0
# IBM      0
# TSLA     0
# GOOG     0
# sp500    0
# dtype: int64

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2159 entries, 0 to 2158
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2159 non-null   object
#  1   AAPL    2159 non-null   float64
#  2   BA      2159 non-null   float64
#  3   T       2159 non-null   float64
#  4   MGM     2159 non-null   float64
#  5   AMZN    2159 non-null   float64
#  6   IBM     2159 non-null   float64
#  7   TSLA    2159 non-null   float64
#  8   GOOG    2159 non-null   float64
#  9   sp500   2159 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 168.8+ KB

# %%
def show_plot(df, fig_title):
  df.plot(x='Date', figsize =(15,7),linewidth=3, title = fig_title)
  plt.grid()
  plt.show()

# %%
show_plot(stock_df, 'RAW STOCK PRICES(WITHOUT NORMALIZATION)')

# %%
def normalized(df):
  x=df.copy()
  for i in x.columns[1:]:
    x[i] = x[i]/x[i][0]
  return x

# %%
normalized(stocks_df)
# Out:
#             Date      AAPL        BA  ...       TSLA      GOOG     sp500
# 13    01-02-2012  1.082584  0.998146  ...   1.047080  0.922479  1.022069
# 264   01-02-2013  1.076485  0.991524  ...   1.355752  1.231815  1.168020
# 1018  01-02-2016  1.601865  1.609853  ...   6.971328  2.397620  1.497013
# 1271  01-02-2017  2.138755  2.171500  ...   8.822655  2.536934  1.759591
# 1523  01-02-2018  2.787109  4.727056  ...  12.362832  3.723006  2.178294
# ...          ...       ...       ...  ...        ...       ...       ...
# 494   31-12-2013  1.331356  1.807575  ...   5.324956  1.779922  1.426754
# 746   31-12-2014  1.833598  1.721361  ...   7.872920  1.673739  1.589270
# 998   31-12-2015  1.748547  1.914846  ...   8.495929  2.419556  1.577723
# 1752  31-12-2018  2.620328  4.270957  ...  11.780531  3.301860  1.935044
# 2004  31-12-2019  4.878023  4.314131  ...  14.808141  4.262853  2.493848
#
# [2159 rows x 10 columns]

# %%
show_plot(normalized(stock_df), 'NORMALIZED STOCKS')

# %%
def interactive_plot(df,title):
  fig = px.line(title = title)

  for i in df.columns[1:]:
    fig.add_scatter(x= df['Date'] ,y= df[i], name = i)

  fig.show()

# %%
interactive_plot(stock_df, 'Prices')

# %%
interactive_plot(normalized(stock_df), 'NORMALIZED PRICE')

# %%
sp_df = stock_df['sp500']
sp_df
# Out:
# 0       1295.500000
# 1       1289.089966
# 2       1293.670044
# 3       1308.040039
# 4       1314.500000
#            ...
# 2154    3327.770020
# 2155    3349.159912
# 2156    3351.280029
# 2157    3360.469971
# 2158    3333.689941
# Name: sp500, Length: 2159, dtype: float64

# %%
df_daily_return = sp_df.copy()

for i in range(1, len(sp_df)):
  df_daily_return[i] = ((sp_df[i]-sp_df[i-1])/sp_df[i-1]) * 100

df_daily_return[0] = 0

# %%
df_daily_return
# Out:
# 0       0.000000
# 1      -0.494792
# 2       0.355295
# 3       1.110793
# 4       0.493866
#           ...
# 2154    0.642974
# 2155    0.642770
# 2156    0.063303
# 2157    0.274222
# 2158   -0.796913
# Name: sp500, Length: 2159, dtype: float64

# %%
a_df = stock_df['AMZN']

a_df_dailyReturn = a_df.copy()

for i in range(1, len(a_df)):
  a_df_dailyReturn[i] = ((a_df[i]-a_df[i-1])/a_df[i-1])*100

a_df_dailyReturn[0] = 0

# %%
a_df_dailyReturn
# Out:
# 0       0.000000
# 1       1.415339
# 2       1.815943
# 3       4.282725
# 4       2.644634
#           ...
# 2154    2.109065
# 2155    0.623082
# 2156   -1.784187
# 2157   -0.609323
# 2158   -2.143792
# Name: AMZN, Length: 2159, dtype: float64

# %%
def daily_return(df):
  df_daily_return = df.copy()

  for i in df.columns[1:]:
    for j in range(1, len(df)):
      df_daily_return[i][j] = ((df[i][j] - df[i][j-1])/df[i][j-1])*100

    df_daily_return[i][0] = 0
    
  return df_daily_return

# %%
stocks_daily_return = daily_return(stock_df)
stocks_daily_return
# Out:
#             Date      AAPL        BA  ...       TSLA      GOOG     sp500
# 0     12-01-2012  0.000000  0.000000  ...   0.000000  0.000000  0.000000
# 1     13-01-2012 -0.374946 -1.205144  ... -19.327430 -0.738516 -0.494792
# 2     17-01-2012  1.164812  0.857909  ...  16.717854  0.574410  0.355295
# 3     18-01-2012  1.038382 -0.239234  ...   0.789470  0.688856  1.110793
# 4     19-01-2012 -0.316937  0.666134  ...  -0.186494  1.052283  0.493866
# ...          ...       ...       ...  ...        ...       ...       ...
# 2154  05-08-2020  0.362467  5.579446  ...  -0.133153  0.589774  0.642974
# 2155  06-08-2020  3.488923 -1.193483  ...   0.307062  1.797626  0.642770
# 2156  07-08-2020 -2.449458 -1.265966  ...  -2.475194 -0.373974  0.063303
# 2157  10-08-2020  1.453480  5.522880  ...  -2.350092  0.107728  0.274222
# 2158  11-08-2020 -2.973987  0.401316  ...  -3.114399 -1.054744 -0.796913
#
# [2159 rows x 10 columns]

# %%
show_plot(stocks_daily_return,'STOCKS DAILY RETURN')

# %%
interactive_plot(stocks_daily_return, 'INTERACTIVE STOCKS')

# %%
cr = stocks_daily_return.drop(columns=['Date']).corr()

# %%
plt.figure(figsize= (10,10))
sns.heatmap(cr, annot= True)

# %%
stocks_daily_return.hist(figsize=(10,10),bins=40);

# %%
df_hist = stocks_daily_return.copy()

df_hist = df_hist.drop(columns = ['Date'])

data = []

for i in df_hist.columns:
  data.append(stocks_daily_return[i].values)

data
# Out:
# [array([ 0.        , -0.37494578,  1.16481192, ..., -2.44945751,
#          1.45347999, -2.9739868 ]),
#  array([ 0.        , -1.20514366,  0.85790887, ..., -1.26596576,
#          5.52287953,  0.40131597]),
#  array([ 0.        , -0.16600597,  0.59860326, ...,  0.60321716,
#          0.5996036 ,  0.        ]),
#  array([ 0.        ,  1.81368508, -0.8097166 , ...,  3.08776831,
#         13.76772918, -0.69284065]),
#  array([ 0.        ,  1.41533854,  1.8159433 , ..., -1.78418726,
#         -0.60932259, -2.14379167]),
#  array([ 0.        , -0.76986928,  0.46885241, ..., -0.91976211,
#          1.72055219, -0.28322004]),
#  array([  0.        , -19.32743009,  16.71785359, ...,  -2.47519409,
#          -2.35009162,  -3.1143992 ]),
#  array([ 0.        , -0.73851634,  0.57441015, ..., -0.37397414,
#          0.10772812, -1.05474435]),
#  array([ 0.        , -0.49479228,  0.35529545, ...,  0.06330295,
#          0.27422185, -0.79691324])]

# %%
fig = ff.create_distplot(data, df_hist.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b8b2cb9d-37ef-4665-996b-08768d716a11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b8b2cb9d-37ef-4665-996b-08768d716a11")) {
#                     Plotly.newPlot(
#                         'b8b2cb9d-37ef-4665-996b-08768d716a11',
# ...
